# %%
import pandas as pd
from dotenv import dotenv_values
from googleapiclient.discovery import build
from IPython.display import JSON

config = dotenv_values(".env")
api_key = config["API_key"]

type(api_key)
# Out:
# str

# %%
channel_ids = ['UC8butISFwT-Wl7EV0hUK0BQ', ]
api_service_name = "youtube"
api_version = "v3"
playlist_id = "UU8butISFwT-Wl7EV0hUK0BQ"

youtube = build(
    api_service_name, api_version, developerKey=api_key)

# %%
def get_channel_stats(youtube, channel_ids):
    """
    Get channel stats
    
    Params:
    ------
    youtube: build object of Youtube API
    channel_ids: list of channel IDs
    
    Returns:
    ------
    dataframe with all channel stats for each channel ID
    
    """

    all_data = []

    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=','.join(channel_ids)
    )
    response = request.execute()

    # loop through items
    for item in response['items']:
        data = {'channelName': item['snippet']['title'],
                'subscribers': item['statistics']['subscriberCount'],
                'views': item['statistics']['viewCount'],
                'totalVideos': item['statistics']['videoCount'],
                'playlistId': item['contentDetails']['relatedPlaylists']['uploads']
                }

        all_data.append(data)

    return pd.DataFrame(all_data)


def get_video_ids(youtube, playlist_id):

    video_ids = []

    request = youtube.playlistItems().list(
        part="snippet,contentDetails",
        playlistId=playlist_id,
        maxResults=50
    )
    response = request.execute()

    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])

    next_page_token = response.get('nextPageToken')
    while next_page_token is not None:
        request = youtube.playlistItems().list(
            part='contentDetails',
            playlistId=playlist_id,
            maxResults=50,
            pageToken=next_page_token)
        response = request.execute()

        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])

        next_page_token = response.get('nextPageToken')

    return video_ids


def get_video_details(youtube, video_ids):

    all_video_info = []

    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute()

        for video in response['items']:
            stats_to_keep = {'snippet': ['channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                             'contentDetails': ['duration', 'definition', 'caption']
                             }
            video_info = {}
            video_info['video_id'] = video['id']

            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            all_video_info.append(video_info)

    return pd.DataFrame(all_video_info)

# %%
channel_stats = get_channel_stats(youtube, channel_ids)

# %%
channel_stats
# Out:
#         channelName subscribers      views totalVideos  \
# 0  freeCodeCamp.org     7800000  547218932        1456
#
#                  playlistId
# 0  UU8butISFwT-Wl7EV0hUK0BQ

# %%
# Get video IDs
video_ids = get_video_ids(youtube, playlist_id)
video_df = get_video_details(youtube, video_ids)
video_df
# Out:
#          video_id      channelTitle  \
# 0     jlogLBkPZ2A  freeCodeCamp.org
# 1     GnodscC2p-A  freeCodeCamp.org
# 2     qrZGfBBlXpk  freeCodeCamp.org
# 3     FRmCxj9K7II  freeCodeCamp.org
# 4     GizsSo-EevA  freeCodeCamp.org
# ...           ...               ...
# 1452  _uWzpyr_5qk  freeCodeCamp.org
# 1453  xXLj5MbrI44  freeCodeCamp.org
# 1454  veugT7A9psY  freeCodeCamp.org
# 1455  xj9mFD71Vfc  freeCodeCamp.org
# 1456  q7tlgZg4Q1o  freeCodeCamp.org
#
#                                                   title  \
# 0     Build AI Apps with ChatGPT, DALL-E, and GPT-4 ...
# 1     Build and Deploy a LeetCode Clone with React, ...
# 2                         Django ChatGPT Clone Tutorial
# 3     Full-Stack Next.js, TypeScript, and AWS Course...
# 4     Use ChatGPT to Code a Full Stack App – Full Co...
# ...                                                 ...
# 1452        Computer Basics 5: How To Measure Data Size
# 1453        Computer Basics 4: Decoding a Binary Number
# 1454            Computer Basics 3: Intro to Binary Code
# 1455          Computer Basics 2: More Computer Hardware
# 1456  Computer Basics 1: The 4 Basic Parts of a Comp...
#
#                                             description  \
# 0     This course will teach you how to build AI-pow...
# 1     In this project tutorial, you will build a Lee...
# 2     Learn how to use Django and the OpenAI API to ...
# 3     Learn how to use Next.js, TypeScript, and AWS ...
# 4     Learn how to use ChatGPT for full stack develo...
# ...                                                 ...
# 1452  http://FreeCodeCamp.com is a community of busy...
# 1453  http://FreeCodeCamp.com is a community of busy...
# 1454  http://FreeCodeCamp.com is a community of busy...
# 1455  http://FreeCodeCamp.com is a community of busy...
# 1456  http://FreeCodeCamp.com is a community of busy...
#
#                                                    tags           publishedAt  \
# 0                                                  None  2023-05-30T15:14:01Z
# 1                                                  None  2023-05-25T14:33:36Z
# 2                                                  None  2023-05-24T14:53:19Z
# 3                                                  None  2023-05-22T15:08:54Z
# 4                                                  None  2023-05-18T14:08:51Z
# ...                                                 ...                   ...
# 1452  [Free Code Camp, JavaScript, Pair Programming,...  2015-07-17T08:31:23Z
# 1453  [Free Code Camp, JavaScript, Pair Programming,...  2015-07-17T08:31:20Z
# 1454  [Free Code Camp, JavaScript, Pair Programming,...  2015-07-17T08:31:17Z
# 1455  [Free Code Camp, JavaScript, Pair Programming,...  2015-07-17T08:31:14Z
# 1456  [Free Code Camp, JavaScript, Pair Programming,...  2015-07-17T08:31:10Z
#
#      viewCount likeCount favouriteCount commentCount    duration definition  \
# 0        23806      1278           None           36  PT4H34M58S         hd
# 1        42667      1562           None           71     PT7H10M         hd
# 2        28681       995           None           47  PT1H33M32S         hd
# 3        50682      1928           None           50    PT6H6M1S         hd
# 4       131418      4181           None          163  PT2H16M31S         hd
# ...        ...       ...            ...          ...         ...        ...
# 1452     47695      None           None           32     PT2M24S         hd
# 1453     62101      None           None           33     PT1M42S         hd
# 1454     52721      None           None           12        PT1M         hd
# 1455     60667      None           None           16     PT1M12S         hd
# 1456    140277      None           None           65      PT1M4S         hd
#
#      caption
# 0      false
# 1      false
# 2       true
# 3      false
# 4      false
# ...      ...
# 1452   false
# 1453    true
# 1454    true
# 1455    true
# 1456    true
#
# [1457 rows x 13 columns]

# %%
video_df[['duration']].sort_values('duration')
# Out:
#            duration
# 406             P0D
# 187   P1DT12H39M22S
# 99     P1DT1H37M26S
# 94       P1DT51M37S
# 147    P1DT7H54M31S
# ...             ...
# 1322        PT9M53S
# 1360        PT9M54S
# 1006        PT9M56S
# 1252         PT9M5S
# 771          PT9M5S
#
# [1457 rows x 1 columns]

# %%
video_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1457 entries, 0 to 1456
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   video_id        1457 non-null   object
#  1   channelTitle    1457 non-null   object
#  2   title           1457 non-null   object
#  3   description     1457 non-null   object
#  4   tags            966 non-null    object
#  5   publishedAt     1457 non-null   object
#  6   viewCount       1457 non-null   object
#  7   likeCount       1434 non-null   object
#  8   favouriteCount  0 non-null      object
#  9   commentCount    1457 non-null   object
#  10  duration        1457 non-null   object
#  11  definition      1457 non-null   object
#  12  caption         1457 non-null   object
# dtypes: object(13)
# memory usage: 148.1+ KB
